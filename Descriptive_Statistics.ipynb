# %% [markdown]
# #Descriptive Statistics

# %% [markdown]
# # .Q1: Understanding Central Tendency (Easy)
#   A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
#
# What is the most representative value of their weekly sales, and why?
# -> the most representative value of the bakerys
#  weekly muffin sales is 12 dozen
#
#
#
#  .when the data is ordered
#  [10,11,12,12,13,14,15],the median is 12,which liesnin the middle.
#  . 12 is also thr mode (it occurs most often ).
#  . the mean (average) is slightly higher because of bigger values like 14 and 15 .
# #Q2: Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
#
# What is the mean score, and what does it tell us about the class’s performance?
# . Marks:12,15,14,16,18,20,19
# MEAN=12+15+14+16+18+20+19=
#              7
# # interpretation
# .the mean score is approximately 16.3 marks .
# .this tells us that ,on averge ,student in the class scored around 16 marks in the quiz.
#  .slince most scores are close to this value and fairly high, it indicates overall good class performance.
# .Q3: Mode in Real Life (Easy)
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
# .shoe size sold:7,8,8,8,9,9,9,10,17
# MODE
# .THE mode is 8 because it appears most frequently(3times)
# ## why this is useful for the store manager
# . size 8 is the most popular shoe size.
# .the manager can stock mare size 8 shoes to meet coustmer demand.
# .this helps reduce shortages, improve sales,and manage inventery efficiently.
# #   Medium Level
# Q4: Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
#
# Why is the median a better measure than the mean in this case? Calculate the median.
# .USED CAR PRICES;
# $8000,$9500,$10200,$10500,$11000,$50000
# CALCULATE THE MEDIEN
# the prices are already in ascending order.
# there are 5 values,so the median is the middle (3rd) value:
# #  median=$10200
#
# why the medien is better than the mean
# .the price $50,000 is an extreme value (outleir)compared to the other cars.
# .the mean would be pulled much higher by this one expensive car .
# .this medien is not afeected by outliers,so it better represents the typical used car price.
#
# Q5: Dispersion Introduction (Medium)
#
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
#
# What does the range tell us about the variation in the student’s puzzle-solving time?
#
# .Puzzle time (minutes);25,30,27,35,40
# calculate range:  RANGE=MAXIUM VALUE -MINIMUM VALUE RANGE =40-25=15 MINUTES
# WHAT the range tells us
# .the range of 15 minutes shows the spread of the student's puzzle-solving times.
# .this means the student's fastest time was 25 min,and the slowest was 40min.
# .A range this size indicates there is noticeble varition in how long the student takes to finish the puzzle each day.
# Q6: Range in Action (Medium)
#
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
#
# Find the range. How can this help the farmer in planning his packaging?
# .week apple harvest weight (Kg):100,105,98,110,120
# # calculte the range
# RANGE=MAX-MIN=120-98
# HOW TO HELPS THE FARMER IN PLANING PACKING
# .A range of 22 kg shows how much the harvest varies from week to week.
# .the farmer can plan flexible packinging (e.g.,extra boxes or storage space) to handle heaveir weeks.
# .it helps avoid shortages of packinging in high-yeild weeks and wastages in low-yeild weeks.
# Q7: Variance for Decision-Making (Medium)
#
# Two delivery companies track delivery delays (in minutes).
#
#
# .Company A: variance = 6
#
#
# .Company B: variance = 15
#
#  Which company is more consistent, and why?
# # company A is more consistant.
# Reason:
# variance shows how much the delivery delays vary from the average. A smaller variance means the delays are more similar each time .
# . company A's variance =6(less spread)
#        -. company B's variance =15( more spread) .
